# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns

# Load the dataset
data = pd.read_csv("Recoded.csv")

# Define categorical and continuous variables
categorical_vars = ['CustName', 'WHName', 'cityrecode', 'regionrecode', 'staterecode', 'productcoderecode']
continuous_var = 'QTY'

# Split the dataset into training and testing sets
seed = 42
train_data, test_data = train_test_split(data, test_size=0.2, random_state=seed)

# Prepare the data
X_train = train_data.drop(columns=[continuous_var])
y_train = train_data[continuous_var]
X_test = test_data.drop(columns=[continuous_var])
y_test = test_data[continuous_var]

# Define the Random Forest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=seed)

# Fit the model to the training data
rf_model.fit(X_train, y_train)

# Predict demand using the Random Forest model
rf_predictions = rf_model.predict(X_test)

# Create a dataframe with actual and predicted demand
predictions = pd.DataFrame({'Actual_Demand': y_test, 'Predicted_Demand': rf_predictions})

# Visualize demand distribution using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=predictions, x='Actual_Demand', bins=30, kde=True, color='blue', label='Actual Demand')
sns.histplot(data=predictions, x='Predicted_Demand', bins=30, kde=True, color='green', label='Predicted Demand')
plt.title("Demand Distribution (Actual vs. Predicted) - Random Forest")
plt.xlabel("Demand")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# Create a scatterplot of actual vs. predicted demand
plt.figure(figsize=(8, 6))
sns.scatterplot(data=predictions, x='Actual_Demand', y='Predicted_Demand', color='green', label='Predicted Demand')
sns.regplot(data=predictions, x='Actual_Demand', y='Predicted_Demand', scatter=False, color='blue', label='Actual Demand')
plt.title("Actual vs. Predicted Demand (Random Forest)")
plt.xlabel("Actual Demand")
plt.ylabel("Predicted Demand")
plt.legend()
plt.show()

# %%
rmse_rf = mean_squared_error(y_test, rf_predictions, squared=False)
print("Random Forest RMSE:", rmse_rf)
# Out:
# Random Forest RMSE: 61.42920300956336

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns

# Load the dataset
data = pd.read_csv("Recoded.csv")

# Define categorical and continuous variables
categorical_vars = ['CustName', 'WHName', 'cityrecode', 'regionrecode', 'staterecode', 'productcoderecode']
continuous_var = 'QTY'

# Split the dataset into training and testing sets
seed = 42
train_data, test_data = train_test_split(data, test_size=0.2, random_state=seed)

# Prepare the data
X_train = train_data.drop(columns=[continuous_var])
y_train = train_data[continuous_var]
X_test = test_data.drop(columns=[continuous_var])
y_test = test_data[continuous_var]

# Define the Decision Tree model
tree_model = DecisionTreeRegressor(random_state=seed)

# Fit the model to the training data
tree_model.fit(X_train, y_train)

# Predict demand using the Decision Tree model
tree_predictions = tree_model.predict(X_test)

# Create a dataframe with actual and predicted demand
predictions = pd.DataFrame({'Actual_Demand': y_test, 'Predicted_Demand': tree_predictions})

# Visualize demand distribution using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=predictions, x='Actual_Demand', bins=30, kde=True, color='blue', label='Actual Demand')
sns.histplot(data=predictions, x='Predicted_Demand', bins=30, kde=True, color='orange', label='Predicted Demand')
plt.title("Demand Distribution (Actual vs. Predicted) - Decision Tree")
plt.xlabel("Demand")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# Create a scatterplot of actual vs. predicted demand
plt.figure(figsize=(8, 6))
sns.scatterplot(data=predictions, x='Predicted_Demand', y='Actual_Demand', color='orange', label='Predicted Demand')
sns.regplot(data=predictions, x='Predicted_Demand', y='Actual_Demand', scatter=False, color='blue', label='Actual Demand')
plt.title("Actual vs. Predicted Demand (Decision Tree)")
plt.xlabel("Predicted Demand")
plt.ylabel("Actual Demand")
plt.legend()
plt.show()

# %%
# Calculate the RMSE
rmse = mean_squared_error(predictions['Actual_Demand'], predictions['Predicted_Demand'], squared=False)
print(f"Root Mean Square Error (RMSE): {rmse}")
# Out:
# Root Mean Square Error (RMSE): 65.72892077492213

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns

# Load the dataset
data = pd.read_csv("Recoded.csv")

# Define categorical and continuous variables
categorical_vars = ['CustName', 'WHName', 'cityrecode', 'regionrecode', 'staterecode', 'productcoderecode']
continuous_var = 'QTY'

# Split the dataset into training and testing sets
seed = 42
train_data, test_data = train_test_split(data, test_size=0.2, random_state=seed)

# Prepare the data
X_train = train_data.drop(columns=[continuous_var])
y_train = train_data[continuous_var]
X_test = test_data.drop(columns=[continuous_var])
y_test = test_data[continuous_var]

# Define the Decision Tree model
tree_model = DecisionTreeRegressor(random_state=seed)

# Fit the model to the training data
tree_model.fit(X_train, y_train)

# Predict demand using the Decision Tree model
tree_predictions = tree_model.predict(X_test)

# Create a dataframe with actual and predicted demand
predictions = pd.DataFrame({'Actual_Demand': y_test, 'Predicted_Demand': tree_predictions})

# Visualize demand distribution using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=predictions, x='Actual_Demand', bins=30, kde=True, color='blue')
plt.title("Demand Distribution (Decision Tree)")
plt.xlabel("Demand")
plt.ylabel("Frequency")
plt.show()

# Create a scatterplot of actual vs. predicted demand
plt.figure(figsize=(8, 6))
sns.scatterplot(data=predictions, x='Actual_Demand', y='Predicted_Demand', color='blue')
sns.regplot(data=predictions, x='Actual_Demand', y='Predicted_Demand', scatter=False, color='red')
plt.title("Actual vs. Predicted Demand (Decision Tree)")
plt.xlabel("Actual Demand")
plt.ylabel("Predicted Demand")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
import seaborn as sns

# Load the dataset
data = pd.read_csv("Recoded.csv")

# Define categorical and continuous variables
categorical_vars = ['CustName', 'WHName', 'cityrecode', 'regionrecode', 'staterecode', 'productcoderecode']
continuous_var = 'QTY'

# Split the dataset into training and testing sets
seed = 42
train_data, test_data = train_test_split(data, test_size=0.2, random_state=seed)

# Prepare the data
X_train = train_data.drop(columns=[continuous_var])
y_train = train_data[continuous_var]
X_test = test_data.drop(columns=[continuous_var])
y_test = test_data[continuous_var]

# Define the Decision Tree model
tree_model = DecisionTreeRegressor(random_state=seed)

# Fit the model to the training data
tree_model.fit(X_train, y_train)

# Predict demand using the Decision Tree model
tree_predictions = tree_model.predict(X_test)

# Create a dataframe with actual and predicted demand
predictions = pd.DataFrame({'Actual_Demand': y_test, 'Predicted_Demand': tree_predictions})

# Visualize demand distribution using a histogram
plt.figure(figsize=(8, 6))
sns.histplot(data=predictions, x='Actual_Demand', bins=30, kde=True, color='blue', label='Actual')
sns.histplot(data=predictions, x='Predicted_Demand', bins=30, kde=True, color='red', label='Predicted')
plt.title("Demand Distribution (Decision Tree)")
plt.xlabel("Demand")
plt.ylabel("Frequency")
plt.legend()
plt.show()

# Create a scatterplot of actual vs. predicted demand
plt.figure(figsize=(8, 6))
sns.scatterplot(data=predictions, x='Actual_Demand', y='Predicted_Demand', color='blue', label='Actual')
sns.regplot(data=predictions, x='Actual_Demand', y='Predicted_Demand', scatter=False, color='red', label='Predicted')
plt.title("Actual vs. Predicted Demand (Decision Tree)")
plt.xlabel("Actual Demand")
plt.ylabel("Predicted Demand")
plt.legend()
plt.show()
